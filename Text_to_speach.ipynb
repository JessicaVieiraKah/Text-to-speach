# %% [markdown]
# <a href="https://colab.research.google.com/github/JessicaVieiraKah/Text-to-speach/blob/main/Text_to_speach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install gTTS

# %%
from gtts import gTTS
text_to_say = "Hello World"
language = 'en'
gtts_object = gTTS(text=text_to_say, lang=language, slow=False)
gtts_object.save("hello.mp3")

# %%
from IPython.display import Audio
Audio("hello.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from gtts import gTTS
text_to_say = "On va se promener aujourd’hui ?"
language = 'fr'
gtts_object = gTTS(text=text_to_say, lang=language, slow=False)
gtts_object.save("On va se promener aujourd’hui ?.mp3")

# %%
from IPython.display import Audio
Audio("On va se promener aujourd’hui ?.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
